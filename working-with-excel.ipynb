# %%
import pandas as pd

# %%
df = pd.read_excel('GlobalSuperstore.xlsx' )
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2017-07-31 2017-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2018-02-05 2018-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2018-10-17 2018-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2018-01-28 2018-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2018-11-05 2018-11-06      Same Day     RH-9495
#
#        Segment           City            State        Country  ...  \
# 0     Consumer  New York City         New York  United States  ...
# 1    Corporate     Wollongong  New South Wales      Australia  ...
# 2     Consumer       Brisbane       Queensland      Australia  ...
# 3  Home Office         Berlin           Berlin        Germany  ...
# 4     Consumer          Dakar            Dakar        Senegal  ...
#
#          Product ID    Category Sub-Category  \
# 0   TEC-AC-10003033  Technology  Accessories
# ...

# %%
df = pd.read_excel('GlobalSuperstore.xlsx', sheet_name='Orders' )
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2017-07-31 2017-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2018-02-05 2018-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2018-10-17 2018-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2018-01-28 2018-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2018-11-05 2018-11-06      Same Day     RH-9495
#
#        Segment           City            State        Country  ...  \
# 0     Consumer  New York City         New York  United States  ...
# 1    Corporate     Wollongong  New South Wales      Australia  ...
# 2     Consumer       Brisbane       Queensland      Australia  ...
# 3  Home Office         Berlin           Berlin        Germany  ...
# 4     Consumer          Dakar            Dakar        Senegal  ...
#
#          Product ID    Category Sub-Category  \
# 0   TEC-AC-10003033  Technology  Accessories
# ...

# %%
df = pd.read_excel('GlobalSuperstore.xlsx', sheet_name='People' )
df.head()
# Out:
#               Person   Region
# 0      Anna Andreadi  Central
# 1        Chuck Magee    South
# 2     Kelly Williams     East
# 3     Matt Collister     West
# 4  Deborah Brumfield   Africa
